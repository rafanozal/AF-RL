# %%
# Google Drive library
from google.colab import drive

# Nombre de los directorios con los ficheros
PROJECT_FOLDER = "/content/drive/My Drive/Colab Notebooks/"
LIBRARY_FOLDER = PROJECT_FOLDER + "/Librerias/"

# !pip install kora -q
from kora import drive
drive.link_nbs()

import LIBRARY_FOLDER + Pintar_figuras

# %%
# Example usage:
variable_names = ['Var1', 'Var2', 'Var3']
values = [10, 20, 30]
Pintar_figuras.create_barplot(variable_names, values, 'Example Bar Plot', 'skyblue', (8, 6))


# Example usage:
variable_names = ['Var1', 'Var2', 'Var3']
values = [10, 20, 30]
Pintar_figuras.create_horizontal_barplot(variable_names, values, 'Example Horizontal Bar Plot', 'skyblue', (8, 6))
